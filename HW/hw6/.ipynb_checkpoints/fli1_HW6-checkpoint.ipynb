# %% [markdown]
# # HW 6 -  Working with Dates
# ANALYST: Fan Li
#
# DUE DATE: Dec 1, 2020
#
# PURPOSE: To work with date values, create plot and aggregate date
#
# ###### SETUPS

# %%
# import libraries
import numpy as np
import pandas as pd
import datetime as dt

# %%
# read in datasets with the Date column set to be the index value
ibm=pd.read_csv("../../data/IBM.csv",index_col='Date',parse_dates=[0])
ibm.head()
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 1962-01-02  7.713333  7.713333  7.626667  7.626667   1.970992  387200
# 1962-01-03  7.626667  7.693333  7.626667  7.693333   1.988223  288000
# 1962-01-04  7.693333  7.693333  7.613333  7.616667   1.968407  256000
# 1962-01-05  7.606667  7.606667  7.453333  7.466667   1.929643  363200
# 1962-01-08  7.460000  7.460000  7.266667  7.326667   1.893463  544000

# %% [markdown]
# 2. Get the data representing the quarterly means of each column and store it in a new
# object called “ibm_qtr.”

# %%
ibm_qtr=ibm.resample('Q').mean()
ibm_qtr
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1962-03-31    7.336561    7.370053    7.296455    7.322434    1.892523
# 1962-06-30    5.777725    5.855529    5.666376    5.734788    1.482393
# 1962-09-30    5.047090    5.110847    5.001429    5.048492    1.305245
# 1962-12-31    4.950688    5.010794    4.903915    4.954233    1.281142
# 1963-03-31    5.486720    5.521425    5.462285    5.490484    1.420132
# ...                ...         ...         ...         ...         ...
# 2018-12-31  125.887778  127.268888  124.232063  125.542064  120.488633
# 2019-03-31  133.109180  134.048198  132.309345  133.334099  129.652061
# 2019-06-30  137.304920  138.276032  136.444920  137.413652  135.110963
# 2019-09-30  141.117345  142.267500  139.863438  141.094689  140.382214
# 2019-12-31  139.241112  140.050557  137.941110  139.115001  139.115001
#
#                   Volume
# Date
# 1962-03-31  3.149460e+05
# 1962-06-30  2.073168e+06
# ...

# %% [markdown]
# 3. Plot the closing price (y-axis) versus the quarter designation (x-axis) using the
# plot() method built into the data frame object. Because the quarter designation is the index of
# “ibm_qtr,” plot() will default to using it as the x-axis, so you don’t have to worry about it.
# Just specify the y-value.

# %%
ibm_qtr.plot(y='Close');

# %% [markdown]
# 4. Create another set of data representing the weekly totals of each column and save it
# in a new object called “ibm_wk.”

# %%
ibm_wk=ibm.resample('W').sum()
ibm_wk
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1962-01-07   30.640000   30.706666   30.320000   30.403334    7.857265
# 1962-01-14   37.213334   37.506667   37.020001   37.193334    9.612035
# 1962-01-21   37.280000   37.396667   37.020000   37.133332    9.596532
# 1962-01-28   36.623334   36.833332   36.350000   36.463335    9.423381
# 1962-02-04   36.076666   36.479999   35.830000   36.156666    9.344124
# ...                ...         ...         ...         ...         ...
# 2019-09-29  713.010009  717.710006  706.280015  713.700012  713.700012
# 2019-10-06  715.189987  721.320022  708.049988  715.780013  715.780013
# 2019-10-13  704.810012  709.779999  700.429993  703.220002  703.220002
# 2019-10-20  696.559997  699.589996  689.680008  695.499985  695.499985
# 2019-10-27  533.510010  536.790023  528.509995  534.990021  534.990021
#
#               Volume
# Date
# 1962-01-07   1294400
# 1962-01-14   2084800
# 1962-01-21   1692800
# ...

# %% [markdown]
# 5. Using print() statements, display the 3 smallest and 3 largest volume weeks in the
# weekly data. [A couple of dataframe methods used in HW 5 will be helpful here.]

# %%
print(ibm_wk.loc[ibm_wk['Volume'].nsmallest(3).index],'\n'*2,
     ibm_wk.loc[ibm_wk['Volume'].nlargest(3).index])
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 1965-11-28  35.900000  36.166667  35.754167  35.783333   9.284139  598400
# 1967-01-01  36.728125  37.012500  36.559375  36.831250   9.567860  798400
# 1969-04-06  46.900000  47.000000  46.562500  46.737500  12.279013  918400
#
#                   Open       High        Low      Close  Adj Close     Volume
# Date
# 1992-12-20   70.28125   71.21875   67.65625   68.81250  41.871697  175357600
# 1995-09-17  119.96875  121.00000  116.87500  118.53125  76.334987  169902800
# 1996-04-21  138.96875  141.31250  134.43750  136.43750  88.282109  145222800

# %%
ibm_wk.nsmallest(3,"Volume")
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 1965-11-28  35.900000  36.166667  35.754167  35.783333   9.284139  598400
# 1967-01-01  36.728125  37.012500  36.559375  36.831250   9.567860  798400
# 1969-04-06  46.900000  47.000000  46.562500  46.737500  12.279013  918400
